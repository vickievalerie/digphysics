# %%
import pandas as pd
import numpy as np
df=pd.read_csv('PHYZLO09.CSV',skiprows=range (1,5))
df.head()
# Out:
#    frame  time   temp    a0  temp_pres  pressure  altitude  humidity  temp_hum
# 0      4  2929  17.00  1023       20.0     98595    229.73      29.7      21.2
# 1      5  3540  17.00  1023       20.0     98595    229.73      29.7      21.2
# 2      6  4152  16.88  1023       20.0     98599    229.64      29.7      21.2
# 3      7  4763  16.88  1023       20.0     98596    229.64      29.7      21.2
# 4      8  5378  16.75  1023       20.0     98593    229.64      31.2      21.1

# %%
# df = df[np.isfinite(df['temp_hum'])]
df=df.iloc[200:-120:15, :]
df['press']=(df['pressure']-df['pressure'].min())/50.0
df.head()
# Out:
#      frame    time  temp    a0  temp_pres  pressure  altitude  humidity  \
# 200    204  126009  6.56  1023       20.0     98594    229.30      35.3
# 215    219  135261  6.31  1022       20.0     98597    229.73      35.5
# 230    234  144610  5.94  1021       20.0     98589    229.64      35.7
# 245    249  153849  5.63  1023       20.1     98588    229.81      36.0
# 260    264  163096  5.31  1023       20.1     98594    230.41      36.1
#
#      temp_hum  press
# 200      19.0  12.12
# 215      18.9  12.18
# 230      18.8  12.02
# 245      18.7  12.00
# 260      18.6  12.12

# %%
df.plot('time',['temp','temp_hum','press','humidity'])

# %%
df['pressure'].min()
# Out:
# 97988

# %%
l = [('a',1),('b',2)]
' '.join([str(x) for x in [1,2,3]))
# Out:
#   File "<ipython-input-45-ea04f08cc712>", line 2
#     ' '.join([str(x) for x in [1,2,3]))
#                                      ^
# SyntaxError: invalid syntax

# %%
print(''.join([(x,'=',y) for i,j in zip(fields,x.split(','))]))
